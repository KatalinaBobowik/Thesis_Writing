# %% [markdown]
# # load libraries

# %% [markdown]
# First load librraies

# %%
library(viridis)
library(Rcmdr)

# %% [markdown]
# REad summary file and tidy up

# %%
a=read.table("/Users/katalinabobowik/Documents/UniMelb_PhD/Thesis_Writing/nReads_AllSamples.txt", header=T)
a=a[1:123,1:5]
rownames(a)=make.unique(as.character(a[,1]))
a$Sample = NULL

# %%
par(mar=c(6.1,4.1,10.1,2.1), xpd=T)
barplot(colPercents(t(a))[1:4,]/100, col=viridis(4), cex.names=0.75, las=3, main="Percentage of Reads \n All filtering stages")
# legend("topright", col=viridis(4), legend=colnames(a), pch=15, cex=0.8)
legend(135,1.15, col=viridis(4), legend=colnames(a), pch=15, cex=0.7)
# Out:
# Plot with title “Percentage of Reads
#  All filtering stages”
